# %%
import pandas as pd

# %%
from nba_api.stats.static import players
player_dict = players.get_active_players()

print('Number of players fetched: {}'.format(len(player_dict)))
# Out:
# Number of players fetched: 519

# %%
nba_players = pd.DataFrame(player_dict)
nba_players.head()
# Out:
#         id                 full_name first_name         last_name  is_active
# 0   203500              Steven Adams     Steven             Adams       True
# 1  1628389               Bam Adebayo        Bam           Adebayo       True
# 2   200746         LaMarcus Aldridge   LaMarcus          Aldridge       True
# 3  1629734            Kyle Alexander       Kyle         Alexander       True
# 4  1629638  Nickeil Alexander-Walker    Nickeil  Alexander-Walker       True

# %%
nba_players.id = nba_players.id.astype('str')

# %%
nba_players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 519 entries, 0 to 518
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          519 non-null    object
#  1   full_name   519 non-null    object
#  2   first_name  519 non-null    object
#  3   last_name   519 non-null    object
#  4   is_active   519 non-null    bool
# dtypes: bool(1), object(4)
# memory usage: 16.9+ KB

# %%
nba_players
# Out:
#           id                 full_name first_name         last_name  is_active
# 0     203500              Steven Adams     Steven             Adams       True
# 1    1628389               Bam Adebayo        Bam           Adebayo       True
# 2     200746         LaMarcus Aldridge   LaMarcus          Aldridge       True
# 3    1629734            Kyle Alexander       Kyle         Alexander       True
# 4    1629638  Nickeil Alexander-Walker    Nickeil  Alexander-Walker       True
# ..       ...                       ...        ...               ...        ...
# 514   201152            Thaddeus Young   Thaddeus             Young       True
# 515  1629027                Trae Young       Trae             Young       True
# 516   203469               Cody Zeller       Cody            Zeller       True
# 517  1627790                Ante Zizic       Ante             Zizic       True
# 518  1627826               Ivica Zubac      Ivica             Zubac       True
#
# [519 rows x 5 columns]

# %%
from nba_api.stats.endpoints import playerawards

playerawards.PlayerAwards(player_id='2544').get_data_frames()[0]
# Out:
#      PERSON_ID FIRST_NAME LAST_NAME                 TEAM  \
# 0         2544     LeBron     James  Cleveland Cavaliers
# 1         2544     LeBron     James  Cleveland Cavaliers
# 2         2544     LeBron     James                  USA
# 3         2544     LeBron     James           Miami Heat
# 4         2544     LeBron     James  Cleveland Cavaliers
# ..         ...        ...       ...                  ...
# 141       2544     LeBron     James   Los Angeles Lakers
# 142       2544     LeBron     James   Los Angeles Lakers
# 143       2544     LeBron     James   Los Angeles Lakers
# 144       2544     LeBron     James   Los Angeles Lakers
# 145       2544     LeBron     James   Los Angeles Lakers
#
#                  DESCRIPTION ALL_NBA_TEAM_NUMBER   SEASON       MONTH  \
# 0     NBA Player of the Week                None  2008-09        None
# 1     NBA Player of the Week                None  2008-09        None
# ...

# %%
from nba_api.stats.static import teams 
teams_dict = teams.get_teams()

print('Number of teams fetched: {}'.format(len(teams_dict)))
# Out:
# Number of teams fetched: 30

# %%
nba_teams = pd.DataFrame(teams_dict)
nba_teams.head()
# Out:
#            id             full_name abbreviation   nickname         city  \
# 0  1610612737         Atlanta Hawks          ATL      Hawks      Atlanta
# 1  1610612738        Boston Celtics          BOS    Celtics       Boston
# 2  1610612739   Cleveland Cavaliers          CLE  Cavaliers    Cleveland
# 3  1610612740  New Orleans Pelicans          NOP   Pelicans  New Orleans
# 4  1610612741         Chicago Bulls          CHI      Bulls      Chicago
#
#            state  year_founded
# 0        Atlanta          1949
# 1  Massachusetts          1946
# 2           Ohio          1970
# 3      Louisiana          2002
# 4       Illinois          1966

# %%
from nba_api.stats.endpoints import playercareerstats
# Anthony Davis
career = playercareerstats.PlayerCareerStats(player_id='203076')
career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     203076   2012-13        00  1610612740               NOH        20.0
# 1     203076   2013-14        00  1610612740               NOP        21.0
# 2     203076   2014-15        00  1610612740               NOP        22.0
# 3     203076   2015-16        00  1610612740               NOP        23.0
# 4     203076   2016-17        00  1610612740               NOP        24.0
# 5     203076   2017-18        00  1610612740               NOP        25.0
# 6     203076   2018-19        00  1610612740               NOP        26.0
# 7     203076   2019-20        00  1610612747               LAL        27.0
#
#    GP  GS     MIN  FGM  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
# 0  64  60  1846.0  349  ...   0.751   165   357  522   63   75  112   89  158
# 1  67  66  2358.0  522  ...   0.791   207   466  673  105   89  189  109  200
# ...

# %%
player_stats = []
for player in nba_players.id:
    player_stats.append(playercareerstats.PlayerCareerStats(player_id=player))
# Out:
# ---------------------------------------------------------------------------
# SysCallError                              Traceback (most recent call last)
# /opt/anaconda3/envs/env1/lib/python3.8/site-packages/urllib3/contrib/pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     455             try:
# --> 456                 cnx.do_handshake()
#     457             except OpenSSL.SSL.WantReadError:
#
# /opt/anaconda3/envs/env1/lib/python3.8/site-packages/OpenSSL/SSL.py in do_handshake(self)
#    1933         result = _lib.SSL_do_handshake(self._ssl)
# -> 1934         self._raise_ssl_error(self._ssl, result)
#    1935
#
# /opt/anaconda3/envs/env1/lib/python3.8/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1662                     if errno != 0:
# -> 1663                         raise SysCallError(errno, errorcode.get(errno))
#    1664                 raise SysCallError(-1, "Unexpected EOF")
# ...

# %%
player_stats.get_data_frames()[0]
